# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores.

ds = pd.read_csv("assets/real_estate.csv", sep=";")
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
mval = ds["price"].max()
id_mval = ds["price"].idxmax()
dirc = ds.loc[id_mval,"address"]
print("La casa con dirección en", dirc.title(),", Nº", id_mval+1, "es la más cara y su precio es de:", mval,"€")
# Out:
# La casa con dirección en El Escorial , Nº 13111 es la más cara y su precio es de: 8500000 €

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
mval = ds["price"].min()
id_mval = ds["price"].idxmin()
dirc = ds.loc[id_mval,"address"]
print("La casa con dirección en", dirc.title(),", Nº", id_mval+1, "es la más barata y su precio es de:", mval,"€")
# Out:
# La casa con dirección en Parla , Nº 367 es la más barata y su precio es de: 0 €

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
#Búsqueda de la vivienda más grande:

mval = ds["surface"].max()
id_mval = ds["surface"].idxmax()
dirc = ds.loc[id_mval,"address"]
print("La casa con dirección en", dirc.title(),", Nº", id_mval+1, "es la más grande y su superficie es de:", mval,"metros.")

#Búsqueda de la vivienda más pequeña:
print()
mval = ds["surface"].min()
id_mval = ds["surface"].idxmin()
dirc = ds.loc[id_mval,"address"]
print("La casa con dirección en", dirc.title(),", Nº", id_mval+1, "es la más pequeña y su superficie es de:", mval,"metros.")
# Out:
# La casa con dirección en Sevilla La Nueva , Nº 6795 es la más grande y su superficie es de: 249000.0 metros.
#
# La casa con dirección en Calle Amparo,  Madrid Capital , Nº 499 es la más pequeña y su superficie es de: 15.0 metros.

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
pbl5 = ds["level5"].unique()
resl = ", ".join(pbl5)
print(resl)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bus
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
import numpy as np
noad = ds.isnull().any()
for columna, tiene_nan in noad.items():
    print(f"Columna: {columna} --> {tiene_nan}")
# Out:
# Columna: Unnamed: 0 --> False
# Columna: id_realEstates --> False
# Columna: isNew --> False
# Columna: realEstate_name --> True
# Columna: phone_realEstate --> True
# Columna: url_inmueble --> False
# Columna: rooms --> True
# Columna: bathrooms --> True
# Columna: surface --> True
# Columna: price --> False
# Columna: date --> False
# Columna: description --> True
# Columna: address --> False
# Columna: country --> False
# Columna: level1 --> False
# Columna: level2 --> False
# Columna: level3 --> False
# Columna: level4 --> True
# Columna: level5 --> False
# Columna: level6 --> True
# Columna: level7 --> True
# Columna: level8 --> True
# Columna: upperLevel --> False
# Columna: countryId --> False
# Columna: level1Id --> False
# Columna: level2Id --> False
# Columna: level3Id --> False
# Columna: level4Id --> False
# Columna: level5Id --> False
# Columna: level6Id --> False
# Columna: level7Id --> False
# Columna: level8Id --> False
# Columna: accuracy --> False
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
dimen = ds.shape
print("Antes de las Eliminaciones:")
print(f"Dimensiones Totales del DataFrame: {dimen}")
print(f"Número de Filas: {dimen[0]}")
print(f"Número de Columnas: {dimen[1]}")
dstotal = ds.dropna(axis=1)
print()
dimen2 = dstotal.shape
print("Después de las Eliminaciones:")
print(f"Dimensiones Totales del DataFrame: {dimen2}")
print(f"Número de Filas: {dimen2[0]}")
print(f"Número de Columnas: {dimen2[1]}")
dstotal
# Out:
# Antes de las Eliminaciones:
# Dimensiones Totales del DataFrame: (15335, 37)
# Número de Filas: 15335
# Número de Columnas: 37
#
# Después de las Eliminaciones:
# Dimensiones Totales del DataFrame: (15335, 25)
# Número de Filas: 15335
# Número de Columnas: 25
#        Unnamed: 0  id_realEstates  isNew  \
# 0               1       153771986  False
# 1               2       153867863  False
# 2               3       153430440  False
# 3               4       152776331  False
# 4               5       153180188  False
# ...           ...             ...    ...
# 15330       15331       153901377  False
# 15331       15332       150394373  False
# 15332       15333       153901397  False
# 15333       15334       152607440  False
# 15334       15335       153901356  False
#
#                                             url_inmueble   price  \
# 0      https://www.fotocasa.es/es/comprar/vivienda/ma...  195000
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...   89000
# ...

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
import math
filtr = ds["level5"] == "Arroyomolinos (Madrid)"
ds_def = ds[filtr]
promd = ds_def["price"].mean()
print("El promedio de los precios pertecientes a los inmuebles de la población de Arroyomolinos, Madrid, es de:", math.ceil(promd), "€.")
# Out:
# El promedio de los precios pertecientes a los inmuebles de la población de Arroyomolinos, Madrid, es de: 294542 €.

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
filtr = ds["level5"] == "Arroyomolinos (Madrid)"
ds_def = ds[filtr]
precios = ds_def["price"]

plt.figure(figsize=(12, 6))
plt.hist(precios, bins=12, color='skyblue', edgecolor='black', alpha=0.9)

plt.title("Histograma De Los Precios en Arroyomolinos, España: Madrid", fontsize=16)
plt.xlabel("Rangos De Los Precios", fontsize=15)
plt.ylabel("Frecuencia De Aparición", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.9)
plt.tight_layout()

plt.show()

# %% [markdown]
# Este gráfico explica que la mayoría de las casas en Arroyomolinos cuestan, aproximadamente, entre 200.000€ a 400.000€, lo que implica que es una zona de clase media para el contexto económico español, por lo que debe de contar con un buen mantenimiento de servicios básicos, junto a una buena seguridad pública.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
filtr1 = ds["level5"] == "Valdemorillo"
ds_def1 = ds[filtr1]
promd1 = ds_def1["price"].mean()
print("El promedio de los precios pertecientes a los inmuebles de la población de Valdemorillo es de:", math.ceil(promd1), "€.")
print()

filtr2 = ds["level5"] == "Galapagar"
ds_def2 = ds[filtr2]
promd2 = ds_def2["price"].mean()
print("El promedio de los precios pertecientes a los inmuebles de la población de Galapagar es de:", math.ceil(promd2), "€.")
print()

if promd1 == promd2:
    print("Efectivamente, son iguales.")
else:
    print("No son iguales.")
# Out:
# El promedio de los precios pertecientes a los inmuebles de la población de Valdemorillo es de: 363861 €.
#
# El promedio de los precios pertecientes a los inmuebles de la población de Galapagar es de: 360064 €.
#
# No son iguales.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
ds_def1 = ds_def1.copy()
ds_def1["pps"] = ds_def1["price"] / ds_def1["surface"]
prm1 = ds_def1["pps"].mean()
print("El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Valdemorillo es de:", math.ceil(prm1), "€/m².")
print()

ds_def2 = ds_def2.copy()
ds_def2["pps"] = ds_def2["price"] / ds_def2["surface"]
prm2 = ds_def2["pps"].mean()
print("El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Galapagar es de:", math.ceil(prm2), "€/m².")
print()

if prm1 == prm2:
    print("Efectivamente, son iguales.")
else:
    print("No son iguales.")
# Out:
# El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Valdemorillo es de: 1318 €/m².
#
# El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Galapagar es de: 1607 €/m².
#
# No son iguales.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.figure(figsize=(12, 6))
plt.scatter(ds['price'], ds['surface'], color='blue', alpha=0.6, edgecolors='black')

plt.xscale('log')
plt.yscale('log')
plt.xlabel("Superficie (m²)", fontsize=12)
plt.ylabel("Precio del Inmueble (€)", fontsize=12)
plt.title("Relación entre Superficie y Precio de Bienes Inmuebles", fontsize=15)
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %% [markdown]
# Los valores se representaban ineficazmente si empleaba una escala normal, la escala logarítmica logra alcanzar una mayor claridad, existe una relación entre ambas columnas, de forma que mientras más vaya aumentando la superficie del bien inmueble, más se incrementará el precio de la vivienda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
filtrodeinmb = ds[ds['realEstate_name'].str.contains('inmobiliaria', case=False, na=False)]
print(f"Hay un total de {len(filtrodeinmb)} bienes raíces.")
# Out:
# Hay un total de 2253 bienes raíces.

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
modanonum = ds['level5'].mode()[0]
print(f"Es: {modanonum}, algo coherente.")
# Out:
# Es:  Madrid Capital, algo coherente.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
dsfsur = ds[ds['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
dsfsur
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
sur_Esp = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
medns = []

for lug in sur_Esp:
    ftr = ds["level5"] == lug
    dsfsr = ds[ftr].sort_values(by='price', ascending=False)
    prmd = dsfsr["price"].median()
    print(f"La mediana de los precios pertecientes a los inmuebles de la población de {lug} es de:", math.ceil(prmd), "€.")
    print()
    medns.append({"Población": lug, "Mediana Precio (€)": math.ceil(prmd)})
ds_medns = pd.DataFrame(medns)

plt.figure(figsize = (12, 6))

plt.bar(ds_medns['Población'], ds_medns['Mediana Precio (€)'], edgecolor='black', linewidth=1)

plt.xlabel("Zonas del Sur de Madrid")
plt.ylabel("Mediana de Los Precios")
plt.title("Mediana de Precios en El Sur de Madrid")

plt.show()
# Out:
# La mediana de los precios pertecientes a los inmuebles de la población de Fuenlabrada es de: 155000 €.
#
# La mediana de los precios pertecientes a los inmuebles de la población de Leganés es de: 169950 €.
#
# La mediana de los precios pertecientes a los inmuebles de la población de Getafe es de: 285305 €.
#
# La mediana de los precios pertecientes a los inmuebles de la población de Alcorcón es de: 179500 €.

# %% [markdown]
# Es posible observar que la zona conocida como Getafe es poseedora de una mediana significativamente superior a la de las demás zonas, esto probablemente implica que dentro del sur de Madrid sea la zona con mayor prestigio.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
clmnadg = ["price", "rooms", "surface", "bathrooms"]

for lag in clmnadg:
    print(f"El promedio de la columna '{lag}' es: {math.ceil(dsfsr[lag].mean())}")
    print()
    print(f"La varianza de la columna '{lag}' es: {math.ceil(dsfsr[lag].var())}")
    print()
# Out:
# El promedio de la columna 'price' es: 230072
#
# La varianza de la columna 'price' es: 15947825984
#
# El promedio de la columna 'rooms' es: 3
#
# La varianza de la columna 'rooms' es: 1
#
# El promedio de la columna 'surface' es: 106
#
# La varianza de la columna 'surface' es: 4245
#
# El promedio de la columna 'bathrooms' es: 2
#
# La varianza de la columna 'bathrooms' es: 1

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
pobunic = dsfsur['level5'].unique()
for lig in pobunic:
    filtr = dsfsur["level5"] == lig
    ds_fordef = dsfsur[filtr]
    direccion_max = ds_fordef.loc[ds_fordef['price'].idxmax(), 'address']
    precio_max = ds_fordef['price'].max()
    print(f"La casa más cara de la zona {lig}, con dirección {direccion_max} vale {precio_max}€.")
    print()
# Out:
# La casa más cara de la zona Fuenlabrada, con dirección Calle de Paulo Freire, 5, Fuenlabrada vale 490000€.
#
# La casa más cara de la zona Alcorcón, con dirección Alcorcón vale 950000€.
#
# La casa más cara de la zona Leganés, con dirección Avenida Reina Sofía, Leganés vale 650000€.
#
# La casa más cara de la zona Getafe, con dirección Getafe vale 1050000€.

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
dsfsur = dsfsur.copy()
dsfsur['price_normal'] = dsfsur.groupby('level5')['price'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
pobl4 = dsfsur['level5'].unique()

plt.figure(figsize=(12, 6))

for laeg in pobl4:
    subset = dsfsur[dsfsur['level5'] == laeg]['price_normal']
    plt.hist(subset, bins=21, alpha=0.6, label=f'Población(level5): {laeg}')

plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.title('Distribución de Precios Normalizados por Población')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# De este gráfico se puede deducir que la grandísima mayoría de sitios cuentan con unos precios que tienden al extremo más bajo, siendo los sitios con un precio alto exponencialmente menores, se puede anotar un específico énfasis en la zona de Getafe que cuenta con muchos sitios acercándose al precio medio.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
dsfsura = dsfsur[dsfsur['level5'] == "Getafe"].copy()
dsfsurb = dsfsur[dsfsur['level5'] == "Alcorcón"].copy()

dsfsura["pps"] = dsfsura["price"] / dsfsura["surface"].replace(0, float('nan'))
dsfsurb["pps"] = dsfsurb["price"] / dsfsurb["surface"].replace(0, float('nan'))

print("El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Getafe es de:", math.ceil(dsfsura["pps"].mean()), "€/m².")
print("Su mediana es de:", math.ceil(dsfsura["pps"].median()), "€/m².")
print("Su número de elementos es de:", math.ceil(dsfsura["pps"].count()), "€/m².")
print("La suma de todos los precios por metro cuadrado sería de:", math.ceil(dsfsura["pps"].sum()), "€/m².")
print()
print("El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Alcorcón es de:", math.ceil(dsfsurb["pps"].mean()), "€/m².")
print("Su mediana es de:", math.ceil(dsfsurb["pps"].median()), "€/m².")
print("Su número de elementos es de:", math.ceil(dsfsurb["pps"].count()), "€/m².")
print("La suma de todos los precios por metro cuadrado sería de:", math.ceil(dsfsurb["pps"].sum()), "€/m².")
print()
print("Los datos expresan que Alcorcón pese a ser más pequeña, es igualmente una zona de mayor estatus económico que Getafe.")
# Out:
# El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Getafe es de: 2067 €/m².
# Su mediana es de: 1974 €/m².
# Su número de elementos es de: 241 €/m².
# La suma de todos los precios por metro cuadrado sería de: 497982 €/m².
#
# El promedio de los precios por metro cuadrado pertecientes a los inmuebles de la población de Alcorcón es de: 2240 €/m².
# Su mediana es de: 2208 €/m².
# Su número de elementos es de: 173 €/m².
# La suma de todos los precios por metro cuadrado sería de: 387400 €/m².
#
# Los datos expresan que Alcorcón pese a ser más pequeña, es igualmente una zona de mayor estatus económico que Getafe.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
dai1 = dsfsur[dsfsur['level5'] == "Fuenlabrada"]
dai2 = dsfsur[dsfsur['level5'] == "Leganés"]
dai3 = dsfsur[dsfsur['level5'] == "Getafe"]
dai4 = dsfsur[dsfsur['level5'] == "Alcorcón"]

fig, axes = plt.subplots(2, 2, figsize=(12, 12))

axes[0, 0].scatter(dai1['surface'], dai1['price'], color='royalblue', alpha=0.6, edgecolors='black')
axes[0, 0].set_title("Fuenlabrada")

axes[0, 1].scatter(dai2['surface'], dai2['price'], color='royalblue', alpha=0.6, edgecolors='black')
axes[0, 1].set_title("Leganés")

axes[1, 0].scatter(dai3['surface'], dai3['price'], color='royalblue', alpha=0.6, edgecolors='black')
axes[1, 0].set_title("Getafe")

axes[1, 1].scatter(dai4['surface'], dai4['price'], color='royalblue', alpha=0.6, edgecolors='black')
axes[1, 1].set_title("Alcorcón")

for ax in axes.flat:
    ax.set_xlabel("Superficie (m²)")
    ax.set_ylabel("Precio (€)")
    ax.grid(True, linestyle="--", alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, Marker

coordenadas = dsfsur[['latitude', 'longitude']].to_dict(orient='records')

m = Map(center=(60, -2.2), zoom=2, min_zoom=1, max_zoom=20)

for coord in coordenadas:
    marker = Marker(location=(coord['latitude'], coord['longitude']))
    m.add_layer(marker)

m
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %% [markdown]
# Este último ejercicio ha sido el único hecho con asistencia de la IA, la razón es que el código original por alguna razón no funcionaba, esto es completamente desconocido así que no conté con los conocimientos para resolver el asunto, incluso a estas instancias, no logra aparecer el mapa.
